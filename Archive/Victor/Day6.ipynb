# %% [markdown]
# # Imports

# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
from testCases_v2 import *
import sklearn
import sklearn.datasets
import sklearn.linear_model
import h5py
from planar_utils import plot_decision_boundary, load_planar_dataset, load_extra_datasets
# %matplotlib inline

np.random.seed(1) # set a seed so that the results are consistent

# %% [markdown]
# # Read cat vs non-cat Data

# %%
train_dataset = h5py.File('../dataset/train_catvnoncat.h5', "r")
train_set_x_orig = np.array(train_dataset["train_set_x"][:]) # train set imagenes
train_set_y = np.array(train_dataset["train_set_y"][:]).reshape(train_set_x_orig.shape[0], 1) # train set etiquetas

test_dataset = h5py.File('../dataset/test_catvnoncat.h5', "r")
test_set_x_orig = np.array(test_dataset["test_set_x"][:]) # test set imagenes
test_set_y = np.array(test_dataset["test_set_y"][:]).reshape(test_set_x_orig.shape[0], 1) # test set etiquetas

print('test images:', test_set_x_orig.shape)
print('train images:', train_set_x_orig.shape)
print('train tags:', train_set_y.shape)
# Out:
# test images: (50, 64, 64, 3)
# train images: (209, 64, 64, 3)
# train tags: (209, 1)

# %% [markdown]
# Visualize one image

# %%
index = 2
plt.imshow(train_set_x_orig[index])
print (f"y = {train_set_y[index]}")
# Out:
# y = [1]

# %% [markdown]
# Convert the input to a one-dimensional array by grouping all the bits in an array sequentially. and normalize the pixels

# %%
train_set_x_flatten = train_set_x_orig.reshape(train_set_x_orig.shape[0],-1)
test_set_x_flatten = test_set_x_orig.reshape(test_set_x_orig.shape[0],-1)

train_set_x_flatten = train_set_x_flatten/255.0
test_set_x_flatten = test_set_x_flatten/255.0

#transpose the data
train_set_x_flatten = train_set_x_flatten.T
train_set_y = train_set_y.T
test_set_x_flatten = test_set_x_flatten.T
test_set_y = test_set_y.T

print ("train_set_x_flatten shape: " + str(train_set_x_flatten.shape))
print ("train_set_y shape: " + str(train_set_y.shape))
print ("test_set_x_flatten shape: " + str(test_set_x_flatten.shape))
print ("test_set_y shape: " + str(test_set_y.shape))
# Out:
# train_set_x_flatten shape: (12288, 209)
# train_set_y shape: (1, 209)
# test_set_x_flatten shape: (12288, 50)
# test_set_y shape: (1, 50)

# %% [markdown]
# **Salida Esperada**:
#
# <table style="width:35%">
#   <tr>
#     <td>train_set_x_flatten shape</td>
#     <td> (12288, 209)</td>
#   </tr>
#   <tr>
#     <td>train_set_y shape</td>
#     <td>(1, 209)</td>
#   </tr>
#   <tr>
#     <td>test_set_x_flatten shape</td>
#     <td>(12288, 50)</td>
#   </tr>
#   <tr>
#     <td>test_set_y shape</td>
#     <td>(1, 50)</td>
#   </tr>
# </table>

# %%
print(test_set_x_flatten)
#print(train_set_x_flatten)
#print(train_set_x_orig)
# Out:
# [[0.61960784 0.45098039 1.         ... 0.16078431 0.07058824 0.52156863]
#  [0.40784314 0.43137255 0.99215686 ... 0.18431373 0.07058824 0.63921569]
#  [0.3254902  0.43529412 0.99607843 ... 0.32941176 0.0627451  0.29411765]
#  ...
#  [0.67843137 0.67058824 0.52156863 ... 0.71764706 0.56470588 0.01960784]
#  [0.50196078 0.69019608 0.39607843 ... 0.55294118 0.5372549  0.08627451]
#  [0.43137255 0.72941176 0.4745098  ... 0.45490196 0.42352941 0.01960784]]

# %% [markdown]
# # Neural Network

# %%
def sigmoid(z):
    """
    Return:
    s -- sigmoid(z)
    """
    
    
    s = 1./(1.+np.exp(-z))
    
    return s

# %%
def layer_sizes(X, Y , H):
    """
    Arguments:
    X -- input dataset of shape (input size, number of examples)
    Y -- labels of shape (output size, number of examples)
    
    Returns:
    n_x -- the size of the input layer
    n_h -- the size of the hidden layer
    n_y -- the size of the output layer
    """

    n_x = X.shape[0]
    n_y = Y.shape[0]
    n_h = H

    return (n_x,n_h, n_y)

# %%
(n_x, n_h, n_y ) = layer_sizes(train_set_x_flatten, train_set_y,4)

print("The size of the input layer is: n_x = " + str(n_x))
print("The size of the hidden layer is: n_h = " + str(n_h))
print("The size of the output layer is: n_y = " + str(n_y))
# Out:
# The size of the input layer is: n_x = 12288
# The size of the hidden layer is: n_h = 4
# The size of the output layer is: n_y = 1

# %% [markdown]
# Initialize parameters

# %%
def initialize_parameters(n_x, n_h, n_y):
    """
    Argument:
    n_x -- size of the input layer
    n_h -- size of the hidden layer
    n_y -- size of the output layer
    
    Returns:
    params -- python dictionary containing your parameters:
                    W1 -- weight matrix of shape (n_h, n_x)
                    b1 -- bias vector of shape (n_h, 1)
                    W2 -- weight matrix of shape (n_y, n_h)
                    b2 -- bias vector of shape (n_y, 1)
    """
    np.random.seed(2)

    W1 = np.random.randn(n_h, n_x) * 0.01
    b1 = np.zeros(shape=(n_h,1))
    W2 = np.random.randn(n_y, n_h) * 0.01
    b2 = np.zeros(shape=(n_y,1))

    #verify
    assert (W1.shape == (n_h, n_x))
    assert (b1.shape == (n_h, 1))
    assert (W2.shape == (n_y, n_h))
    assert (b2.shape == (n_y, 1))

    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %% [markdown]
# Forward Propagation

# %%
def forward_propagation(X, parameters):
    """
    Argument:
    X -- input data of size (n_x, m)
    parameters -- python dictionary containing your parameters (output of initialization function)
    
    Returns:
    A2 -- The sigmoid output of the second activation
    cache -- a dictionary containing "Z1", "A1", "Z2" and "A2"
    """
    W1 = parameters["W1"]
    W2 = parameters["W2"]
    b1 = parameters["b1"]
    b2 = parameters["b2"]

    m = X.shape[1]

    Z1 = W1@X + b1
    A1 = np.tanh(Z1)
    Z2 = W2@A1 + b2
    A2 = sigmoid(Z2)

    assert(A2.shape == (1, m))


    cache = {"Z1": Z1,
             "A1": A1,
             "Z2": Z2,
             "A2": A2}
    return A2, cache

# %% [markdown]
# Compute cost

# %%
def compute_cost(A2, Y):
    """
    Computes the cross-entropy cost given in equation (13)
    
    Arguments:
    A2 -- The sigmoid output of the second activation, of shape (1, number of examples)
    Y -- "true" labels vector of shape (1, number of examples)
    parameters -- python dictionary containing your parameters W1, b1, W2 and b2
    
    Returns:
    cost -- cross-entropy cost given equation (13)
    """
    m = Y.shape[1]
    logprobs = Y * np.log(A2) + (1-Y) * np.log(1-A2)
    cost = -1/m * np.sum(logprobs)
    # cost = -np.sum(Y*np.log(A2) + (1-Y)*np.log(1-A2)) /m

    cost = np.squeeze(cost)     

    assert(isinstance(cost, float))

    return cost

# %% [markdown]
# Backward Propagation

# %%
def backward_propagation(parameters, cache, X, Y):
    """
    Implement the backward propagation using the instructions above.

    Arguments:
    parameters -- python dictionary containing our parameters 
    cache -- a dictionary containing "Z1", "A1", "Z2" and "A2".
    X -- input data of shape (2, number of examples)
    Y -- "true" labels vector of shape (1, number of examples)

    Returns:
    grads -- python dictionary containing your gradients with respect to different parameters
    """

    m = Y.shape[1]

    W1 = parameters["W1"]
    W2 = parameters["W2"]

    A1 = cache["A1"]
    A2 = cache["A2"]

    dZ2 = A2-Y
    dW2 = 1/m * dZ2@A1.T
    db2 = 1/m * np.sum(dZ2,axis=1, keepdims=True)
    dZ1 = W2.T@dZ2 * (1 - A1**2.0) 
    dW1 = 1/m * dZ1@X.T
    db1 = 1/m * np.sum(dZ1, axis=1, keepdims=True)

    grads = {"dW1": dW1,
                "db1": db1,
                "dW2": dW2,
                "db2": db2}

    return grads

# %% [markdown]
# Update parameters

# %%
def update_parameters(parameters, grads, learning_rate = 0.01):
    """
    Updates parameters using the gradient descent update rule given above
    
    Arguments:
    parameters -- python dictionary containing your parameters 
    grads -- python dictionary containing your gradients 
    
    Returns:
    parameters -- python dictionary containing your updated parameters 
    """
    # Retrieve each parameter from the dictionary "parameters"
    ### START CODE HERE ### (≈ 4 lines of code)
    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']
    ### END CODE HERE ###
    
    # Retrieve each gradient from the dictionary "grads"
    ### START CODE HERE ### (≈ 4 lines of code)
    dW1 = grads['dW1']
    db1 = grads['db1']
    dW2 = grads['dW2']
    db2 = grads['db2']

    W1 = W1 - learning_rate * dW1
    b1 = b1 - learning_rate * db1
    W2 = W2 - learning_rate * dW2
    b2 = b2 - learning_rate * db2
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %% [markdown]
# Optimize

# %%
def model( X, Y, n_h, num_iterations = 10000,learning_rate = 0.01, print_cost = False):
    """
    Arguments:
    X -- dataset of shape (2, number of examples)
    Y -- labels of shape (1, number of examples)
    n_h -- size of the hidden layer
    num_iterations -- Number of iterations in gradient descent loop
    print_cost -- if True, print the cost every 1000 iterations
    
    Returns:
    parameters -- parameters learnt by the model. They can then be used to predict.
    """
    np.random.seed(3)
    (n_x, a ,n_y) = layer_sizes(X,Y, n_h)

    parameters = initialize_parameters(n_x, n_h, n_y)
    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']
    print("Ok until init")
    for i in range (0,num_iterations):
        A2,cache = forward_propagation(X, parameters)

        cost = compute_cost(A2, Y)

        grads = backward_propagation(parameters, cache, X, Y)

        parameters = update_parameters(parameters, grads, learning_rate)

        if print_cost and i %100 == 0:
            print("Cost after iteration %i : %f"%(i,cost))

    return parameters

# %% [markdown]
# Predict

# %%
def predict(parameters, X):
    """
    Using the learned parameters, predicts a class for each example in X
    
    Arguments:
    parameters -- python dictionary containing your parameters 
    X -- input data of size (n_x, m)
    
    Returns
    predictions -- vector of predictions of our model (red: 0 / blue: 1)
    """

    A2,cache = forward_propagation(X, parameters)
    predictions = (A2 > 0.5 )*1

    return A2

# %% [markdown]
# Run

# %% [markdown]
# Test with cat vs non-cats data with a good tuning

# %%
parameters = model(train_set_x_flatten, train_set_y, 4, 2001, 0.03, True )

# %%
predictions = predict(parameters, test_set_x_flatten)
predictions_train = predict(parameters, train_set_x_flatten)
print ('Accuracy with train: %d' % float((np.dot(train_set_y,predictions_train.T) + np.dot(1-train_set_y,1-predictions_train.T))/float(train_set_y.size)*100) + '%')
print ('Accuracy with test: %d' % float((np.dot(test_set_y,predictions.T) + np.dot(1-test_set_y,1-predictions.T))/float(test_set_y.size)*100) + '%')
# print (parameters)
# Out:
# Accuracy with train: 96%
# Accuracy with test: 69%
# {'W1': array([[ 0.02050248, -0.01635384, -0.01593666, ..., -0.01628255,
#         -0.0115126 ,  0.03873886],
#        [-0.0023027 ,  0.02103973, -0.01205342, ...,  0.00094511,
#          0.01746198, -0.00297811],
#        [ 0.0079381 , -0.00218283, -0.00967758, ..., -0.01011112,
#         -0.01417542,  0.00926688],
#        [ 0.00418021, -0.01101575, -0.00577224, ..., -0.00137958,
#         -0.02405997,  0.01038371]]), 'b1': array([[-0.03538834],
#        [-0.00821376],
#        [ 0.00507576],
#        [ 0.02111667]]), 'W2': array([[ 2.22803868, -1.16109998,  1.17035062,  1.3031696 ]]), 'b2': array([[0.31281196]])}

# %% [markdown]
# Planar data test

# %%
X, Y = load_planar_dataset()
plt.scatter(X[0, :], X[1, :], c=Y, s=40, cmap=plt.cm.Spectral)

# %%
# Build a model with a n_h-dimensional hidden layer
parameters = model(X, Y, n_h = 4, num_iterations = 10001,learning_rate= 1.2, print_cost=True)

# Plot the decision boundary
plot_decision_boundary(lambda x: predict(parameters, x.T), X, Y)
plt.title("Decision Boundary for hidden layer size " + str(4))
predictions = predict(parameters, X)
print ('Accuracy: %d' % float((np.dot(Y,predictions.T) + np.dot(1-Y,1-predictions.T))/float(Y.size)*100) + '%')
# Out:
# Ok until init
# Cost after iteration 0 : 0.693527
# Cost after iteration 100 : 0.345452
# Cost after iteration 200 : 0.333118
# Cost after iteration 300 : 0.328233
# Cost after iteration 400 : 0.326452
# Cost after iteration 500 : 0.325471
# Cost after iteration 600 : 0.324761
# Cost after iteration 700 : 0.306411
# Cost after iteration 800 : 0.411589
# Cost after iteration 900 : 0.392745
# Cost after iteration 1000 : 0.341439
# Cost after iteration 1100 : 0.327992
# Cost after iteration 1200 : 0.326607
# Cost after iteration 1300 : 0.325628
# Cost after iteration 1400 : 0.324897
# Cost after iteration 1500 : 0.324362
# Cost after iteration 1600 : 0.324038
# Cost after iteration 1700 : 0.323832
# Cost after iteration 1800 : 0.323685
# Cost after iteration 1900 : 0.323572
# Cost after iteration 2000 : 0.323482
# Cost after iteration 2100 : 0.323409
# Cost after iteration 2200 : 0.323349
# Cost after iteration 2300 : 0.323297
# Cost after iteration 2400 : 0.323253
# Cost after iteration 2500 : 0.323215
# Cost after iteration 2600 : 0.323181
# Cost after iteration 2700 : 0.323151
# Cost after iteration 2800 : 0.323125
# Cost after iteration 2900 : 0.323101
# Cost after iteration 3000 : 0.323079
# Cost after iteration 3100 : 0.323059
# Cost after iteration 3200 : 0.323041
# Cost after iteration 3300 : 0.323024
# Cost after iteration 3400 : 0.323008
# Cost after iteration 3500 : 0.322994
# Cost after iteration 3600 : 0.322980
# Cost after iteration 3700 : 0.322968
# Cost after iteration 3800 : 0.322956
# Cost after iteration 3900 : 0.322945
# Cost after iteration 4000 : 0.322935
# Cost after iteration 4100 : 0.322925
# Cost after iteration 4200 : 0.322916
# Cost after iteration 4300 : 0.322907
# Cost after iteration 4400 : 0.322899
# Cost after iteration 4500 : 0.322891
# Cost after iteration 4600 : 0.322884
# Cost after iteration 4700 : 0.322877
# Cost after iteration 4800 : 0.322870
# Cost after iteration 4900 : 0.322864
# Cost after iteration 5000 : 0.322858
# Cost after iteration 5100 : 0.322852
# Cost after iteration 5200 : 0.322846
# Cost after iteration 5300 : 0.322841
# Cost after iteration 5400 : 0.322836
# Cost after iteration 5500 : 0.322831
# Cost after iteration 5600 : 0.322826
# Cost after iteration 5700 : 0.322821
# Cost after iteration 5800 : 0.322817
# Cost after iteration 5900 : 0.322813
# Cost after iteration 6000 : 0.322809
# Cost after iteration 6100 : 0.322805
# Cost after iteration 6200 : 0.322801
# Cost after iteration 6300 : 0.322797
# Cost after iteration 6400 : 0.322794
# Cost after iteration 6500 : 0.322790
# Cost after iteration 6600 : 0.322787
# Cost after iteration 6700 : 0.322784
# Cost after iteration 6800 : 0.322781
# Cost after iteration 6900 : 0.322778
# Cost after iteration 7000 : 0.322775
# Cost after iteration 7100 : 0.322772
# Cost after iteration 7200 : 0.322769
# Cost after iteration 7300 : 0.322766
# Cost after iteration 7400 : 0.322764
# Cost after iteration 7500 : 0.322761
# Cost after iteration 7600 : 0.322759
# Cost after iteration 7700 : 0.322756
# Cost after iteration 7800 : 0.322754
# Cost after iteration 7900 : 0.322752
# Cost after iteration 8000 : 0.322750
# Cost after iteration 8100 : 0.322747
# Cost after iteration 8200 : 0.322745
# Cost after iteration 8300 : 0.322743
# Cost after iteration 8400 : 0.322741
# Cost after iteration 8500 : 0.322739
# Cost after iteration 8600 : 0.322737
# Cost after iteration 8700 : 0.322736
# Cost after iteration 8800 : 0.322734
# Cost after iteration 8900 : 0.322732
# Cost after iteration 9000 : 0.322730
# Cost after iteration 9100 : 0.322729
# Cost after iteration 9200 : 0.322727
# Cost after iteration 9300 : 0.322725
# Cost after iteration 9400 : 0.322724
# Cost after iteration 9500 : 0.322722
# Cost after iteration 9600 : 0.322721
# Cost after iteration 9700 : 0.322719
# Cost after iteration 9800 : 0.322718
# Cost after iteration 9900 : 0.322716
# Cost after iteration 10000 : 0.322715
# Accuracy: 77%

# %% [markdown]
# Tuning hidden layer

# %%
# This may take about 2 minutes to run

plt.figure(figsize=(16, 32))
hidden_layer_sizes = [1, 2, 3, 4, 5, 20, 36]
for i, n_h in enumerate(hidden_layer_sizes):
    plt.subplot(5, 2, i+1)
    plt.title('Hidden Layer of size %d' % n_h)

    parameters =  model(X, Y, n_h, num_iterations = 5000, learning_rate = 1.2)
    plot_decision_boundary(lambda x: predict(parameters, x.T), X, Y)
    predictions = predict(parameters, X)
    accuracy = float((np.dot(Y,predictions.T) + np.dot(1-Y,1-predictions.T))/float(Y.size)*100)
    print ("Accuracy for {} hidden units: {} %".format(n_h, accuracy))
# Out:
# Ok until init
# Accuracy for 1 hidden units: 55.91666101618169 %
# Ok until init
# Accuracy for 2 hidden units: 60.797731948261934 %
# Ok until init
# Accuracy for 4 hidden units: 85.21816916138366 %
# Ok until init
# Accuracy for 8 hidden units: 88.0192476573956 %
# Ok until init
# Accuracy for 16 hidden units: 87.76291091931441 %
# Ok until init
# Accuracy for 32 hidden units: 87.82407914986575 %
# Ok until init
# Accuracy for 64 hidden units: 88.15916926016627 %

# %% [markdown]
# Diferent planar data sets

# %%
# Datasets
noisy_circles, noisy_moons, blobs, gaussian_quantiles, no_structure = load_extra_datasets()

datasets = {"noisy_circles": noisy_circles,
            "noisy_moons": noisy_moons,
            "blobs": blobs,
            "gaussian_quantiles": gaussian_quantiles}

### START CODE HERE ### (choose your dataset)
dataset = "blobs"
### END CODE HERE ###

X, Y = datasets[dataset]
X, Y = X.T, Y.reshape(1, Y.shape[0])

# make blobs binary
if dataset == "blobs":
    Y = Y%2

# Visualize the data
plt.scatter(X[0, :], X[1, :], c=Y, s=40, cmap=plt.cm.Spectral);
